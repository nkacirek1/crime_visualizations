# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %%
shoot = pd.read_csv('denver_police_officer_involved_shootings.csv')

# %%
shoot.head()
# Out:
#    INCIDENT_NUMBER        INCIDENT_DATE  INCIDENT_TIME DAY_OF_WEEK  \
# 0     2.016500e+10  2016-06-12 00:00:00         2129.0      Sunday
# 1     2.016435e+09  2016-07-10 00:00:00          100.0      Sunday
# 2     2.015483e+09  2015-08-22 00:00:00         1906.0    Saturday
# 3     2.017500e+10  2017-05-20 00:00:00          426.0    Saturday
# 4     2.016569e+09  2016-09-05 00:00:00         1207.0      Monday
#
#      INITIAL_CONTACT              CONTACT_BASIS         STREET_ADDRESS  \
# 0  Citizen-Initiated  Weapon / Concealed Weapon       1955 Arapahoe St
# 1  Officer-Initiated                   Shooting        900 blk 14th St
# 2  Officer-Initiated               Vehicle Stop  2800 blk N Fairfax St
# 3  Citizen-Initiated  Suicidal Person / Suicide      2873 S Quitman St
# 4  Officer-Initiated                    Warrant   300 blk N. Osage St.
#
#    CITY_STATE  LAST_FIRST_NAME     ROLE  ... GENDER   AGE RACE ETHNICITY  \
# 0  Denver, CO   Bronish, James  Subject  ...      M  57.0    W        NH
# 1  Denver, CO     Jones, Kevin  Subject  ...      M  40.0    B        NH
# 2  Denver, CO  Sheppard, Jimmy  Officer  ...      M  41.0    B        NH
# 3  Denver, CO     Allred, John  Officer  ...      M  29.0    W         H
# 4  Denver, CO     Scott, Shawn  Subject  ...      M  39.0    W        NH
#
#            ARMED_WITH  DISCHARGED_FIREARM     CASUALTY  \
# 0  Replica or Air Gun                  No      Injured
# 1             Firearm                 Yes      Injured
# 2             Firearm                 Yes  Not Injured
# 3            Stun Gun                  No      Injured
# 4             Firearm                 Yes  Not Injured
#
#                                  DECISION_LETTER_URL X_COORDINATE Y_COORDINATE
# 0  https://www.denverda.org/wp-content/uploads/de...    3142984.0    1699027.0
# 1  https://www.denverda.org/wp-content/uploads/de...    3141492.0    1696618.0
# 2  https://www.denverda.org/wp-content/uploads/de...    3160776.0    1701292.0
# 3  https://www.denverda.org/wp-content/uploads/de...    3128616.0    1666758.0
# 4                                     None available    3139108.0    1688147.0
#
# [5 rows x 24 columns]

# %%
plt.hist('AGE', data=shoot[shoot['ROLE']=='Officer'], alpha=0.6)
plt.title('Age of Officer Involved in Shooting\n')
plt.xlabel('\nAge')
plt.ylabel('Number of Officers\n')
plt.tight_layout()
plt.savefig('Histogram.png')
